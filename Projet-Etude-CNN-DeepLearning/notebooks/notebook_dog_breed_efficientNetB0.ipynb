# %%
import sys
import os
import json

os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import mixed_precision
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense
from tensorflow.keras.applications import MobileNetV2

# %% [markdown]
# # Environnement

# %%
mixed_precision.set_global_policy('mixed_float16')
gpus = tf.config.list_physical_devices('GPU')

ROOT_DIRECTORY = Path.cwd().parent.parent
ETUDE_DIRECTORY = ROOT_DIRECTORY / 'Projet-Etude-CNN-DeepLearning'
DATASET_DIRECTORY = ETUDE_DIRECTORY / "dataset" / "Dog-Breed-Identification"
NOTEBOOKS_DIRECTORY = ETUDE_DIRECTORY / "notebooks"
MODELS_DIRECTORY = ETUDE_DIRECTORY / "models"

TRAIN_DATASET_FOLDER_JPG = DATASET_DIRECTORY / 'train'
TEST_DATASET_FOLDER_JPG = DATASET_DIRECTORY / 'test'
FEATURES_FILE_CSV = DATASET_DIRECTORY / 'labels.csv'

MODEL_NAME = "model_dog_from_efficientnetb0"
MODEL_CHECKPOINT_PATH = MODELS_DIRECTORY / MODEL_NAME / 'checkpoints' / f"{MODEL_NAME}_checkpoint.keras"
MODEL_FINAL_PATH = MODELS_DIRECTORY / MODEL_NAME / f"{MODEL_NAME}.keras"

print(f"""
ROOT_DIRECTORY : {ROOT_DIRECTORY}
ETUDE_DIRECTORY : {ETUDE_DIRECTORY}
DATASET_DIRECTORY : {DATASET_DIRECTORY}
NOTEBOOKS_DIRECTORY : {NOTEBOOKS_DIRECTORY}
MODELS_DIRECTORY : {MODELS_DIRECTORY}
TRAIN_DATASET_FOLDER_JPG : {TRAIN_DATASET_FOLDER_JPG}
TEST_DATASET_FOLDER_JPG : {TEST_DATASET_FOLDER_JPG}
FEATURES_FILE_CSV : {FEATURES_FILE_CSV}
MODEL_NAME : {MODEL_NAME}
MODEL_CHECKPOINT_PATH: {MODEL_CHECKPOINT_PATH}
MODEL_FINAL_PATH : {MODEL_FINAL_PATH}
""")
# Out:
# ROOT_DIRECTORY : /home/leolchalot/Documents/Projets/CNN - Deep Learning
# ETUDE_DIRECTORY : /home/leolchalot/Documents/Projets/CNN - Deep Learning/Projet-Etude-CNN-DeepLearning
# DATASET_DIRECTORY : /home/leolchalot/Documents/Projets/CNN - Deep Learning/Projet-Etude-CNN-DeepLearning/dataset/Dog-Breed-Identification
# NOTEBOOKS_DIRECTORY : /home/leolchalot/Documents/Projets/CNN - Deep Learning/Projet-Etude-CNN-DeepLearning/notebooks
# MODELS_DIRECTORY : /home/leolchalot/Documents/Projets/CNN - Deep Learning/Projet-Etude-CNN-DeepLearning/models
# TRAIN_DATASET_FOLDER_JPG : /home/leolchalot/Documents/Projets/CNN - Deep Learning/Projet-Etude-CNN-DeepLearning/dataset/Dog-Breed-Identification/train
# TEST_DATASET_FOLDER_JPG : /home/leolchalot/Documents/Projets/CNN - Deep Learning/Projet-Etude-CNN-DeepLearning/dataset/Dog-Breed-Identification/test
# FEATURES_FILE_CSV : /home/leolchalot/Documents/Projets/CNN - Deep Learning/Projet-Etude-CNN-DeepLearning/dataset/Dog-Breed-Identification/labels.csv
# MODEL_NAME : model_dog_from_efficientnetb0
# MODEL_CHECKPOINT_PATH: /home/leolchalot/Documents/Projets/CNN - Deep Learning/Projet-Etude-CNN-DeepLearning/models/model_dog_from_efficientnetb0/checkpoints/model_dog_from_efficientnetb0_checkpoint.keras
# MODEL_FINAL_PATH : /home/leolchalot/Documents/Projets/CNN - Deep Learning/Projet-Etude-CNN-DeepLearning/models/model_dog_from_efficientnetb0/model_dog_from_efficientnetb0.keras

# %% [markdown]
# # Configuration matérielle

# %%
def _():
    """
    Show the current hardware configuration
    :return:
    """
    print(f"🐍 Version Python : {sys.version.split()[0]}")
    print(f"🤖 Version TensorFlow : {tf.__version__}")

    try:
        print("\n--- État Système (nvidia-smi) ---")
        # !nvidia-smi
    except Exception as rised_error:
        print(rised_error)

    print("\n--- Détection TensorFlow ---")
    if not gpus:
        print("❌ Aucun GPU détecté par TensorFlow.")
        print("Causes possibles :")
        print("1. Vous n'avez pas installé 'tensorflow[and-cuda]'")
        print("2. Votre version de Python n'est pas supportée.")
        print("3. La variable CUDA_VISIBLE_DEVICES = -1 est restée active.")
    else:
        try:
            for gpu in gpus:
                tf.config.experimental.set_memory_growth(gpu, True)
            print("✅ GPU configuré : Mémoire dynamique activée")
        except RuntimeError as rised_error:
            print(f"Erreur config GPU : {rised_error}")

_()
# Out:
# 🐍 Version Python : 3.10.19
# 🤖 Version TensorFlow : 2.20.0
#
# --- État Système (nvidia-smi) ---
# Fri Jan 30 11:19:31 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.126.09             Driver Version: 580.126.09     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4060 ...    Off |   00000000:01:00.0 Off |                  N/A |
# | N/A   45C    P8              2W /   80W |    1468MiB /   8188MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            3048      G   /usr/lib/xorg/Xorg                       26MiB |
# |    0   N/A  N/A           27686      C   ...envs/tf_gpu_stable/bin/python       1138MiB |
# |    0   N/A  N/A           34952      G   ...share/Steam/ubuntu12_32/steam          2MiB |
# |    0   N/A  N/A           35113      G   ./steamwebhelper                         15MiB |
# |    0   N/A  N/A           35144    C+G   ...am/ubuntu12_64/steamwebhelper          5MiB |
# |    0   N/A  N/A           35862      C   ...envs/tf_gpu_stable/bin/python        222MiB |
# +-----------------------------------------------------------------------------------------+
#
# --- Détection TensorFlow ---
# ✅ GPU configuré : Mémoire dynamique activée

# %% [markdown]
# # Chargement des données

# %%
images_train_dataset = os.listdir(TRAIN_DATASET_FOLDER_JPG)
images_test_dataset = os.listdir(TEST_DATASET_FOLDER_JPG)
labels_df = pd.read_csv(FEATURES_FILE_CSV)
print(' No# of train images in data:', len(images_train_dataset))
print(' No# of test images in data:', len(images_test_dataset))
labels_df.head()
# Out:
#  No# of train images in data: 10222
#  No# of test images in data: 10357
#                                  id             breed
# 0  000bec180eb18c7604dcecc8fe0dba07       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97             dingo
# 2  001cdf01b096e06d78e9e5112d419397          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62  golden_retriever

# %% [markdown]
# # Variables de configuration

# %%
BATCH_SIZE = 32
RANDOM_SEED = 42
SHUFFLE = True
TARGET_SIZE = (224,224)

VALIDATION_SPLIT = 0.2      # 20% des données serviront à la validation
ROTATION_RANGE = 40         # Rotation aléatoire jusqu'à 20 degrés
WIDTH_SHIFT_RANGE = 0.2     # Décalage horizontal
HEIGHT_SHIFT_RANGE = 0.2    # Décalage vertical
HORIZONTAL_FLIP = True      # Retournement horizontal (miroir)
FILL_MODE = "nearest"       # Methode de remplissage des pixels "éteints"

# Reconstitution des noms des fichiers d'images
labels_df['id'] = labels_df['id'].apply(lambda x_name: x_name + ".jpg" if not x_name.endswith(".jpg") else x_name)

# print(labels_df.head())

# %%
# Création du générateur avec augmentation de données
# https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator

# Configuration pour l'entraînement avec augmentation de données
train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=VALIDATION_SPLIT,
    rotation_range=ROTATION_RANGE,
    width_shift_range=WIDTH_SHIFT_RANGE,
    height_shift_range=HEIGHT_SHIFT_RANGE,
    horizontal_flip=HORIZONTAL_FLIP,
    fill_mode=FILL_MODE
)

# Configuration pour la validation
valid_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

# Entraînement
train_generator = train_datagen.flow_from_dataframe(
    dataframe=labels_df,
    directory=TRAIN_DATASET_FOLDER_JPG,
    x_col="id",
    y_col="breed",
    subset="training",
    batch_size=BATCH_SIZE,
    seed=RANDOM_SEED,
    shuffle=SHUFFLE,
    class_mode="categorical",
    target_size=TARGET_SIZE
)

# Validation
valid_generator = valid_datagen.flow_from_dataframe(
    dataframe=labels_df,
    directory=TRAIN_DATASET_FOLDER_JPG,
    x_col="id",
    y_col="breed",
    subset="validation",
    batch_size=BATCH_SIZE,
    seed=RANDOM_SEED,
    shuffle=SHUFFLE,
    class_mode="categorical",
    target_size=TARGET_SIZE
)

# ---- Configuration du déroulement de l'entraînement ----
# 1. Sauvegarde
checkpoint = ModelCheckpoint(MODEL_CHECKPOINT_PATH,
                             monitor='val_accuracy',
                             save_best_only=True,
                             mode='max',
                             verbose=1)

# 2. Arrêt automatique (Patience augmentée à 8, car l'apprentissage from scratch est lent)
early_stop = EarlyStopping(monitor='val_loss',
                           patience=8,
                           restore_best_weights=True)

# 3. Ralentissement automatique (INDISPENSABLE ici)
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.2,    # On divise le Learning Rate par 5
                              patience=3,    # Si pas d'amélioration pendant 3 époques
                              min_lr=1e-6,   # Ne pas descendre trop bas
                              verbose=1)

callbacks_list = [checkpoint, early_stop, reduce_lr]

# print(train_generator.class_indices)
# Out:
# Found 8178 validated image filenames belonging to 120 classes.
# Found 2044 validated image filenames belonging to 120 classes.

# %% [markdown]
# # Architecture du modèle

# %%
# 1. Nettoyage de la mémoire (Important pour effacer le modèle vide précédent)
tf.keras.backend.clear_session()

# 2. Configuration
N_CLASSES = 120  # Nombre de races de chiens
INPUT_SHAPE = (224, 224, 3)

# 3. Chargement du modèle de base (MobileNetV2)
base_model = MobileNetV2(
    weights='imagenet',
    include_top=False,
    input_shape=INPUT_SHAPE
)
base_model.trainable = False # On gèle les poids

# 4. Construction du modèle Final (Approche Séquentielle)
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dropout(0.2),
    Dense(N_CLASSES, activation='softmax')
], name="DogBreedModel")

# 5. Compilation
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# 6. Vérification
model.summary()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1769768372.693721   43462 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4702 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Model: "DogBreedModel"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 120)            │       153,720 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,411,704 (9.20 MB)
#  Trainable params: 153,720 (600.47 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
# 4. Lancement (50 EPOCHS)
history = model.fit(
    train_generator,
    # steps_per_epoch=len(train_generator),
    epochs=50,
    validation_data=valid_generator,
    validation_steps=len(valid_generator),
    callbacks=callbacks_list
)
# Out:
# Epoch 1/50
# 2026-01-30 11:19:39.883248: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-30 11:19:39.967928: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#   1/256 ━━━━━━━━━━━━━━━━━━━━ 30:28 7s/step - accuracy: 0.0000e+00 - loss: 5.2739
# I0000 00:00:1769768381.476281   43529 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 162/256 ━━━━━━━━━━━━━━━━━━━━ 17s 189ms/step - accuracy: 0.1657 - loss: 3.9966
# 2026-01-30 11:20:14.564396: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-30 11:20:14.649519: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.2286 - loss: 3.5649
# 2026-01-30 11:20:39.912898: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-30 11:20:39.997545: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# Epoch 1: val_accuracy improved from None to 0.63552, saving model to /home/leolchalot/Documents/Projets/CNN - Deep Learning/Projet-Etude-CNN-DeepLearning/models/model_dog_from_efficientnetb0/checkpoints/model_dog_from_efficientnetb0_checkpoint.keras
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 67s 235ms/step - accuracy: 0.3672 - loss: 2.6365 - val_accuracy: 0.6355 - val_loss: 1.2902 - learning_rate: 0.0010
# Epoch 2/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.6089 - loss: 1.4561
# Epoch 2: val_accuracy improved from 0.63552 to 0.69276, saving model to /home/leolchalot/Documents/Projets/CNN - Deep Learning/Projet-Etude-CNN-DeepLearning/models/model_dog_from_efficientnetb0/checkpoints/model_dog_from_efficientnetb0_checkpoint.keras
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 52s 205ms/step - accuracy: 0.6030 - loss: 1.4382 - val_accuracy: 0.6928 - val_loss: 1.0636 - learning_rate: 0.0010
# Epoch 3/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.6546 - loss: 1.1959
# Epoch 3: val_accuracy did not improve from 0.69276
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 50s 197ms/step - accuracy: 0.6554 - loss: 1.2046 - val_accuracy: 0.6928 - val_loss: 1.0018 - learning_rate: 0.0010
# Epoch 4/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.6954 - loss: 1.0387
# Epoch 4: val_accuracy improved from 0.69276 to 0.70548, saving model to /home/leolchalot/Documents/Projets/CNN - Deep Learning/Projet-Etude-CNN-DeepLearning/models/model_dog_from_efficientnetb0/checkpoints/model_dog_from_efficientnetb0_checkpoint.keras
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 52s 201ms/step - accuracy: 0.6884 - loss: 1.0781 - val_accuracy: 0.7055 - val_loss: 1.0095 - learning_rate: 0.0010
# Epoch 5/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.7014 - loss: 1.0008
# Epoch 5: val_accuracy improved from 0.70548 to 0.71771, saving model to /home/leolchalot/Documents/Projets/CNN - Deep Learning/Projet-Etude-CNN-DeepLearning/models/model_dog_from_efficientnetb0/checkpoints/model_dog_from_efficientnetb0_checkpoint.keras
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 50s 195ms/step - accuracy: 0.7031 - loss: 1.0061 - val_accuracy: 0.7177 - val_loss: 0.9802 - learning_rate: 0.0010
# Epoch 6/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.7351 - loss: 0.8882
# Epoch 6: val_accuracy did not improve from 0.71771
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 50s 194ms/step - accuracy: 0.7126 - loss: 0.9604 - val_accuracy: 0.7172 - val_loss: 0.9627 - learning_rate: 0.0010
# Epoch 7/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.7290 - loss: 0.9015
# Epoch 7: val_accuracy did not improve from 0.71771
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 50s 194ms/step - accuracy: 0.7288 - loss: 0.8901 - val_accuracy: 0.7114 - val_loss: 0.9837 - learning_rate: 0.0010
# Epoch 8/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.7480 - loss: 0.8333
# Epoch 8: val_accuracy did not improve from 0.71771
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 50s 195ms/step - accuracy: 0.7438 - loss: 0.8535 - val_accuracy: 0.7153 - val_loss: 0.9739 - learning_rate: 0.0010
# Epoch 9/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.7642 - loss: 0.7721
# Epoch 9: val_accuracy improved from 0.71771 to 0.71918, saving model to /home/leolchalot/Documents/Projets/CNN - Deep Learning/Projet-Etude-CNN-DeepLearning/models/model_dog_from_efficientnetb0/checkpoints/model_dog_from_efficientnetb0_checkpoint.keras
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 50s 195ms/step - accuracy: 0.7567 - loss: 0.8088 - val_accuracy: 0.7192 - val_loss: 0.9761 - learning_rate: 0.0010
# Epoch 10/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.7921 - loss: 0.6853
# Epoch 10: val_accuracy improved from 0.71918 to 0.73043, saving model to /home/leolchalot/Documents/Projets/CNN - Deep Learning/Projet-Etude-CNN-DeepLearning/models/model_dog_from_efficientnetb0/checkpoints/model_dog_from_efficientnetb0_checkpoint.keras
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 50s 195ms/step - accuracy: 0.7975 - loss: 0.6744 - val_accuracy: 0.7304 - val_loss: 0.9197 - learning_rate: 2.0000e-04
# Epoch 11/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.8082 - loss: 0.6300
# Epoch 11: val_accuracy did not improve from 0.73043
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 50s 195ms/step - accuracy: 0.7992 - loss: 0.6509 - val_accuracy: 0.7304 - val_loss: 0.9178 - learning_rate: 2.0000e-04
# Epoch 12/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.8075 - loss: 0.6313
# Epoch 12: val_accuracy improved from 0.73043 to 0.73092, saving model to /home/leolchalot/Documents/Projets/CNN - Deep Learning/Projet-Etude-CNN-DeepLearning/models/model_dog_from_efficientnetb0/checkpoints/model_dog_from_efficientnetb0_checkpoint.keras
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 50s 196ms/step - accuracy: 0.8084 - loss: 0.6290 - val_accuracy: 0.7309 - val_loss: 0.9126 - learning_rate: 2.0000e-04
# Epoch 13/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.8149 - loss: 0.6028
# Epoch 13: val_accuracy improved from 0.73092 to 0.73434, saving model to /home/leolchalot/Documents/Projets/CNN - Deep Learning/Projet-Etude-CNN-DeepLearning/models/model_dog_from_efficientnetb0/checkpoints/model_dog_from_efficientnetb0_checkpoint.keras
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 50s 196ms/step - accuracy: 0.8079 - loss: 0.6281 - val_accuracy: 0.7343 - val_loss: 0.9157 - learning_rate: 2.0000e-04
# Epoch 14/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.8093 - loss: 0.6329
# Epoch 14: val_accuracy did not improve from 0.73434
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 50s 194ms/step - accuracy: 0.8031 - loss: 0.6387 - val_accuracy: 0.7334 - val_loss: 0.9183 - learning_rate: 2.0000e-04
# Epoch 15/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.8253 - loss: 0.5930
# Epoch 15: val_accuracy did not improve from 0.73434
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 50s 195ms/step - accuracy: 0.8096 - loss: 0.6274 - val_accuracy: 0.7324 - val_loss: 0.9135 - learning_rate: 2.0000e-04
# Epoch 16/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.8220 - loss: 0.5958
# Epoch 16: val_accuracy did not improve from 0.73434
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 50s 195ms/step - accuracy: 0.8206 - loss: 0.5934 - val_accuracy: 0.7343 - val_loss: 0.9050 - learning_rate: 4.0000e-05
# Epoch 17/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.8266 - loss: 0.5818
# Epoch 17: val_accuracy improved from 0.73434 to 0.73532, saving model to /home/leolchalot/Documents/Projets/CNN - Deep Learning/Projet-Etude-CNN-DeepLearning/models/model_dog_from_efficientnetb0/checkpoints/model_dog_from_efficientnetb0_checkpoint.keras
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 50s 196ms/step - accuracy: 0.8249 - loss: 0.5876 - val_accuracy: 0.7353 - val_loss: 0.9010 - learning_rate: 4.0000e-05
# Epoch 18/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.8292 - loss: 0.5729
# Epoch 18: val_accuracy did not improve from 0.73532
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 50s 194ms/step - accuracy: 0.8258 - loss: 0.5736 - val_accuracy: 0.7348 - val_loss: 0.9026 - learning_rate: 4.0000e-05
# Epoch 19/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.8182 - loss: 0.5871
# Epoch 19: val_accuracy did not improve from 0.73532
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 50s 195ms/step - accuracy: 0.8168 - loss: 0.5898 - val_accuracy: 0.7339 - val_loss: 0.9008 - learning_rate: 4.0000e-05
# Epoch 20/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.8195 - loss: 0.5802
# Epoch 20: val_accuracy improved from 0.73532 to 0.73581, saving model to /home/leolchalot/Documents/Projets/CNN - Deep Learning/Projet-Etude-CNN-DeepLearning/models/model_dog_from_efficientnetb0/checkpoints/model_dog_from_efficientnetb0_checkpoint.keras
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 50s 196ms/step - accuracy: 0.8172 - loss: 0.5938 - val_accuracy: 0.7358 - val_loss: 0.9030 - learning_rate: 4.0000e-05
# Epoch 21/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.8259 - loss: 0.5694
# Epoch 21: val_accuracy improved from 0.73581 to 0.73875, saving model to /home/leolchalot/Documents/Projets/CNN - Deep Learning/Projet-Etude-CNN-DeepLearning/models/model_dog_from_efficientnetb0/checkpoints/model_dog_from_efficientnetb0_checkpoint.keras
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 51s 197ms/step - accuracy: 0.8187 - loss: 0.5790 - val_accuracy: 0.7387 - val_loss: 0.9021 - learning_rate: 4.0000e-05
# Epoch 22/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.8272 - loss: 0.5685
# Epoch 22: val_accuracy did not improve from 0.73875
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 50s 195ms/step - accuracy: 0.8273 - loss: 0.5720 - val_accuracy: 0.7358 - val_loss: 0.9019 - learning_rate: 4.0000e-05
# Epoch 23/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.8191 - loss: 0.5915
# Epoch 23: val_accuracy did not improve from 0.73875
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 50s 194ms/step - accuracy: 0.8221 - loss: 0.5863 - val_accuracy: 0.7348 - val_loss: 0.9020 - learning_rate: 8.0000e-06
# Epoch 24/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.8296 - loss: 0.5611
# Epoch 24: val_accuracy did not improve from 0.73875
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 50s 194ms/step - accuracy: 0.8293 - loss: 0.5628 - val_accuracy: 0.7363 - val_loss: 0.9009 - learning_rate: 8.0000e-06
# Epoch 25/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.8194 - loss: 0.5837
# Epoch 25: val_accuracy did not improve from 0.73875
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 50s 194ms/step - accuracy: 0.8239 - loss: 0.5806 - val_accuracy: 0.7368 - val_loss: 0.9011 - learning_rate: 8.0000e-06
# Epoch 26/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.8250 - loss: 0.5769
# Epoch 26: val_accuracy did not improve from 0.73875
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 50s 194ms/step - accuracy: 0.8251 - loss: 0.5834 - val_accuracy: 0.7373 - val_loss: 0.9011 - learning_rate: 1.6000e-06
# Epoch 27/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.8257 - loss: 0.5719
# Epoch 27: val_accuracy did not improve from 0.73875
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 50s 195ms/step - accuracy: 0.8243 - loss: 0.5731 - val_accuracy: 0.7368 - val_loss: 0.9010 - learning_rate: 1.6000e-06

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(len(acc))

plt.figure(figsize=(12, 6))

# Courbe de Précision
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Entraînement Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Précision (Accuracy)')

# Courbe de Perte
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Entraînement Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Perte (Loss)')
plt.show()

# %%
# Sauvegarde au format de Keras
model.save(MODEL_FINAL_PATH)
print("Modèle sauvegardé avec succès !")
# Out:
# Modèle sauvegardé avec succès !

# %%
labels_map = {v: k for k, v in train_generator.class_indices.items()}

def predict_breed(img_path):
    # Charger l'image et la redimensionner comme à l'entraînement (224x224)
    img = image.load_img(img_path, target_size=(224, 224))

    # Convertir en tableau de nombres (array)
    img_array = image.img_to_array(img)

    # Normaliser (diviser par 255 comme lors de l'entraînement)
    img_array = img_array / 255.0

    # Ajouter une dimension pour simuler un batch de 1 image (1, 224, 224, 3)
    img_array = np.expand_dims(img_array, axis=0)

    # Faire la prédiction
    model_prediction = model.predict(img_array)

    # Trouver l'index de la probabilité la plus élevée
    predicted_class_index = np.argmax(model_prediction)
    confidence = np.max(model_prediction) * 100

    predicted_breed = labels_map[predicted_class_index]

    # Affichage
    plt.imshow(img)
    plt.axis('off')
    plt.title(f"Prédiction : {predicted_breed} ({confidence:.2f}%)")
    plt.show()

# --- UTILISATION ---
# Remplacez par le chemin d'une image de votre dossier de test
test_image_path = os.path.join(TEST_DATASET_FOLDER_JPG, os.listdir(TEST_DATASET_FOLDER_JPG)[3])
predict_breed(test_image_path)
# Out:
# 2026-01-30 11:42:27.129710: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-01-30 11:42:27.212190: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step

# %%
# Récupérer le mapping ({'beagle': 0, 'boxer': 1})
class_indices = train_generator.class_indices

# Inverser pour avoir {0: 'beagle', 1: 'boxer'}
idx_to_class = {v: k for k, v in class_indices.items()}

# Sauvegarder dans un fichier
with open(DATASET_DIRECTORY / 'class_indices.json', 'w') as f:
    json.dump(idx_to_class, f)

print("✅ Fichier class_indices.json généré !")
# Out:
# ✅ Fichier class_indices.json généré !
